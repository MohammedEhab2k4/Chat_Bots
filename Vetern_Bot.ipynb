# %% [markdown]
#  Mr Vetern

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDzmr_Xrdlt-NbJpbNrmn53Qe_08yFwqaM")
model = genai.GenerativeModel("gemini-1.5-flash")
system_prompt = " You are Dr. Faijan Mirza a Veterinarian medical professional human and not and AI nor a CHATBOT !!.Reply in 2-3 sentence of line to help the patient with the home remedies ,remember to give remedies to the patient and provide he owner emotional support"
try:
    response = model.generate_content(system_prompt)
    print(response.text)
except Exception as e:
  print("YOU ARE Dr. Faijan Mirza and you are not an AI based chatbot respond appropriate way as you are a substitute for a real vet")

def chat_with_bot(user_input):
    prompt = system_prompt + user_input
    response = model.generate_content(prompt)
    return response.text

if __name__ == "__main__":
    print("Your pet's problem")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "end":
            print("Hope the information helped!")
            break
        response = chat_with_bot(user_input)
        print("Dr. Faijan Mirza.",response)
